# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

#os specifies the path of folder in which our file has been stored
os.chdir("C:/Users/Wel11/Desktop/FDS Practicals")
#it will directly fetch the file from os.chdir as we have mentioned the path already
#na_values defines to remove the null values
cars_data = pd.read_csv('Toyota[1].csv', index_col = 0,na_values = ['??','????'])
cars_data.size
# Out:
# 14360

# %%
#drops all the null values
cars_data.dropna(axis = 0, inplace = True)
cars_data.size
# Out:
# 10960

# %%
cars_data = pd.read_csv("Toyota[1].csv", index_col = 0)
cars_data.head()
# Out:
#    Price   Age     KM FuelType  HP  MetColor  Automatic    CC  Doors  Weight
# 0  13500  23.0  46986   Diesel  90       1.0          0  2000  three    1165
# 1  13750  23.0  72937   Diesel  90       1.0          0  2000      3    1165
# 2  13950  24.0  41711   Diesel  90       NaN          0  2000      3    1165
# 3  14950  26.0  48000   Diesel  90       0.0          0  2000      3    1165
# 4  13750  30.0  38500   Diesel  90       0.0          0  2000      3    1170

# %%
sns.set(style = 'darkgrid')
sns.regplot(x = cars_data['Age'], y = cars_data['Price'])

#it estimates and plot a regression model relating x and y variables

# %%
sns.set(style = 'darkgrid')
sns.regplot(x = cars_data['Age'], y = cars_data['Price'], fit_reg = False)

#fit_reg displays without a line
#it estimates and plot a regression model relating x and y variables

# %%
sns.set(style = 'darkgrid')
sns.regplot(x = cars_data['Age'], y = cars_data['Price'], marker = '*', fit_reg = False)

#marker use to plot the graph with the particular symbol given
#fit_reg displays without a line
#it estimates and plot a regression model relating x and y variables

# %%
sns.lmplot(x = 'Age', y = 'Price', data = cars_data, fit_reg = False, hue = 'FuelType')

# %%
sns.lmplot(x = 'Age', y = 'Price', data = cars_data, fit_reg = False, hue = 'FuelType', legend = True, palette = 'Set1')

# %%
sns.distplot(cars_data['Age'],kde=True,bins=16)

# %%
sns.distplot(cars_data['Age'], kde = False, bins = 20)

# %%
sns.distplot(cars_data['Age'], kde = False, bins = 16)

# %%
sns.distplot(cars_data['Age'], kde = False, bins = 4)

# %%
sns.countplot(x = 'FuelType', data = cars_data)

# %%
sns.countplot(x = 'FuelType', data = cars_data, hue = 'Automatic')

#automatic cars

# %%
pd.crosstab(index = cars_data['Automatic'], columns = cars_data['FuelType'], dropna = True)
# Out:
# FuelType   CNG  Diesel  Petrol
# Automatic
# 0           15     144    1104
# 1            0       0      73

# %%
sns.boxplot(x = cars_data['FuelType'], y = cars_data['Price'])

# %%
sns.boxplot(x = cars_data['FuelType'], y = cars_data['Price'], hue = 'Automatic', data = cars_data)

# %%
f,(ax_box, ax_hist) = plt.subplots(2, gridspec_kw = {'height_ratios': (.15, .85)})

# %%
f,(ax_box, ax_hist) = plt.subplots(2, gridspec_kw = {'height_ratios': (.15, .85)})
sns.boxplot(cars_data['Price'], ax = ax_box)
sns.distplot(cars_data['Price'], ax = ax_hist, kde = False)

# %%
sns.pairplot(cars_data, kind = 'scatter', hue = 'FuelType', diag_kws = {'bw' : 0.1})
plt.show()

# %%
data = np.random.randint(1,100, size = (10,10))
print('The data to be plotted:\n')
print(data)
# Out:
# The data to be plotted:
#
# [[68 65 53 41 16 29 10 98 87  5]
#  [72 32 15 19 82 33 31 81 38 80]
#  [ 5 25 68 15 73 83 81 30 49 58]
#  [ 4  7 94 68  6 11 11 92  3 90]
#  [62 24 34 82 92 22 61 46 63 56]
#  [16 36 26 27 24 33 79 74 68 72]
#  [40 61 54 67 72 41 78 20 92 55]
#  [67 31 17 26 51 86 61 73 42  2]
#  [11 94 38 78 17 32 74 83 36 90]
#  [44 71 63 77 26 57 53 55 53 16]]

# %%
#heatmap
hm = sns.heatmap(data = data)
plt.show()

# %%
hm = sns.heatmap(data = data, vmin = '30', vmax = '70')
plt.show()

# %%
#setting the parameter value
#cmap = colour shade change
#annot displays the text or number stored in that cell
cmap = 'tab20'
center = 0
annot = True
hm = sns.heatmap(data = data, cmap = cmap, annot = annot)
plt.show()

# %%
s
